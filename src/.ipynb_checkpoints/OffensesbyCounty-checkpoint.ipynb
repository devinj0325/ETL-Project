# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csvfile = "../resources/ca_offenses_by_county.csv"

# %%
csvfile_df = pd.read_csv(csvfile, encoding="ISO-8859-1")

# %%
csvfile_df.head()
# Out:
#   Metropolitan/Nonmetropolitan        County Violent crime  \
# 0        Metropolitan Counties       Alameda           510
# 1        Metropolitan Counties        Butte3           155
# 2        Metropolitan Counties  Contra Costa           426
# 3        Metropolitan Counties    El Dorado3           252
# 4        Metropolitan Counties        Fresno           962
#
#    Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 0                                   6.0                       13.0
# 1                                   4.0                       20.0
# 2                                  14.0                       24.0
# 3                                   9.0                       46.0
# 4                                   8.0                       32.0
#
#    Rape(legacy definition) Robbery Aggravated assault Property crime Burglary  \
# 0                      NaN     177                314          2,077      463
# ...

# %%
csvfile_df.drop("Metropolitan/Nonmetropolitan", axis=1)
csvfile_df
# Out:
#      Metropolitan/Nonmetropolitan            County Violent crime  \
# 0           Metropolitan Counties           Alameda           510
# 1           Metropolitan Counties            Butte3           155
# 2           Metropolitan Counties      Contra Costa           426
# 3           Metropolitan Counties        El Dorado3           252
# 4           Metropolitan Counties            Fresno           962
# 5           Metropolitan Counties         Imperial3           219
# 6           Metropolitan Counties              Kern         2,235
# 7           Metropolitan Counties            Kings3           122
# 8           Metropolitan Counties       Los Angeles         5,173
# 9           Metropolitan Counties            Madera           334
# 10          Metropolitan Counties             Marin            95
# 11          Metropolitan Counties            Merced           432
# 12          Metropolitan Counties          Monterey           244
# ...

# %%
#Extract only the 3 counties needed
county_list = ['Los Angeles', 'Ventura', 'Orange']
cleaned = csvfile_df[csvfile_df['County'].isin(county_list)].copy()

# %%
fips = [6037, 6059, 6111]

# %%
cleaned['FIPS'] = fips

# %%
cleaned.head()
# Out:
#    Metropolitan/Nonmetropolitan       County Violent crime  \
# 8         Metropolitan Counties  Los Angeles         5,173
# 14        Metropolitan Counties       Orange           213
# 33        Metropolitan Counties      Ventura           169
#
#     Murder and nonnegligent manslaughter  Rape (revised definition)  \
# 8                                   98.0                      304.0
# 14                                   2.0                       12.0
# 33                                   3.0                       32.0
#
#     Rape(legacy definition) Robbery Aggravated assault Property crime  \
# 8                       NaN   1,212              3,559         16,301
# 14                      NaN      28                171          1,265
# 33                      NaN      16                118            849
#
#    Burglary Larceny-theft Motor vehicle theft  Arson  FIPS
# 8     3,739         8,359               4,203  215.0  6037
# ...

# %%
#Set county as index

cleaned.set_index('County')
# Out:
#             Metropolitan/Nonmetropolitan Violent crime  \
# County
# Los Angeles        Metropolitan Counties         5,173
# Orange             Metropolitan Counties           213
# Ventura            Metropolitan Counties           169
#
#              Murder and nonnegligent manslaughter  Rape (revised definition)  \
# County
# Los Angeles                                  98.0                      304.0
# Orange                                        2.0                       12.0
# Ventura                                       3.0                       32.0
#
#              Rape(legacy definition) Robbery Aggravated assault  \
# County
# Los Angeles                      NaN   1,212              3,559
# Orange                           NaN      28                171
# Ventura                          NaN      16                118
#
#             Property crime Burglary Larceny-theft Motor vehicle theft  Arson  \
# County
# ...

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5432/offenses_by_county_db')
print(engine)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-5d992333bd9f> in <module>
# ----> 1 engine = create_engine('postgresql://postgres:postgres@localhost:5432/offenses_by_county_db')
#       2 print(engine)
#
# NameError: name 'create_engine' is not defined

# %%
# Use Pandas To Load CSV converted DataFrame into database
properties_selected_df.to_sql(name='offenses_county', con=engine, if_exists='append', index=True, index_label='id')

# %%
# Check For Tables
engine.table_names()

# %%
pd.read_sql_query('SELECT * FROM offenses_county limit 100', con=engine, index_col = 'id').head()
